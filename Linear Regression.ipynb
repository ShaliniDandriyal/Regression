# %% [markdown]
# '''
# Supervised ML algorithims
# 1)Regression(linerar,plynomial,regression trees)- Numeric data
# 2)Classification(Random Forest,Descion Trees,lOGISTICTIC Regression,SVR)- Categorical data
# '''

# %% [markdown]
# linear regression is a statsiticsal method that is used for predictive analysis. Makes predictions for continuous/real or numeric varaiable such as cost ,age etc.

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\ins.csv")
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sn.lineplot(x=df['age'],y=df['premium'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='premium'>

# %%
sn.lmplot(x='age',y='premium',data=df)

# %%
from sklearn import linear_model

# %%
lm=linear_model.LinearRegression()

# %%
# fit accepts data in the form of arrary
lm.fit(X=df[['age']],y=df['premium'])
# Out:
# LinearRegression()

# %%
lm.predict([[40]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([47300.])

# %%
m=lm.coef_

# %%
c=lm.intercept_

# %%
m
# Out:
# array([1780.])

# %%
m=1

# %%
y=m*40+c

# %%
y
# Out:
# array([47300.])

# %%
lm.predict([[40]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([47300.])

# %%
df1=pd.read_csv(r"C:\Users\user\Desktop\area.csv",index_col='S.No')
df1
# Out:
#       Area   Price
# S.No
# 0     2600  550000
# 1     3000  565000
# 2     3200  610000
# 3     3600  680000
# 4     4000  725000

# %%
sn.lmplot(x='Area',y='Price',data=df1)

# %%
lm.fit(X=df1[['Area']],y=df1['Price'])
# Out:
# LinearRegression()

# %%
lm.predict([[3600]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([669452.05479452])
