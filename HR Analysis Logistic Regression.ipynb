# %% [raw]
# Download employee retention dataset from here: https://www.kaggle.com/giripujar/hr-analytics.
#
# Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# Plot bar charts showing impact of employee salaries on retention
# Plot bar charts showing corelation between department and employee retention
# Now build logistic regression model using variables that were narrowed down in step 1
# Measure the accuracy of the model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
Department_=df.groupby('Department')['Department'].agg('count').sort_values(ascending=False)

# %%
Department_
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: Department, dtype: int64

# %%
salary_=df.groupby('salary')['salary'].agg('count').sort_values(ascending=False)

# %%
salary_
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(9,8))
sn.countplot(x='time_spend_company',hue='left',data=df,order=df['time_spend_company'].value_counts().index,palette='flare').set_title("No. of years in company v/s No. of Employee")
plt.ylabel('Employees Count',size=12)
plt.xlabel('No. of years in company',size=12)
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.countplot(x='number_project',hue='left',data=df,order=df['number_project'].value_counts().index,palette='flare').set_title("No. of Project v/s No. of Employee")
plt.ylabel('Employees Count',size=12)
plt.xlabel('No. of Projects',size=12)
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.countplot(x='Work_accident',hue='left',data=df,order=df['Work_accident'].value_counts().index,palette='flare').set_title("No. of Work Accidents v/s No. of Employee")
plt.ylabel('Employees Count',size=12)
plt.xlabel('No. of Work Accidents',size=12)
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.countplot(x='salary',hue='left',data=df,order=df['salary'].value_counts().index,palette='flare').set_title("Salary v/s No. of Employee")
plt.ylabel('Salary',size=12)
plt.xlabel('No. of Work Accidents',size=12)
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.countplot(x='Department',hue='left',data=df,order=df['Department'].value_counts().index,palette='flare').set_title("Departments v/s No. of Employee")
plt.ylabel('Employees Count',size=12)
plt.xlabel('Departments',size=12)
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.boxplot(x='last_evaluation',y='salary',data=df,hue='left')
plt.title("Evaluation Vs Salary",size = 13)
plt.ylabel("Salary" , size = 12 )
plt.xlabel("Evaluation" , size = 12 )
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.boxplot(x='average_montly_hours',y='salary',data=df,hue='left')
plt.title("Average Monthly Hours Vs Salary",size = 13)
plt.ylabel("Salary" , size = 12 )
plt.xlabel("Average Monthly Hours" , size = 12 )
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(9,8))
sn.boxplot(x="satisfaction_level",y='salary',data=df,hue='left')
plt.title("Satisfaction Vs Salary",size = 13)
plt.ylabel("Salary" , size = 12 )
plt.xlabel("Satisfaction Level" , size = 12 )
plt.legend(title = "Left", loc='upper right')
plt.show()

# %%
plt.figure(figsize=(15,7))
sn.kdeplot(df.loc[(df['left'] == 0),'last_evaluation'] , color='red',shade=True,label='Not Left')
sn.kdeplot(df.loc[(df['left'] == 1),'last_evaluation'] , color='purple',shade=True, label='Left')
plt.title('Employee Evaluation Distribution - Left v.s. Not Left',size = 13)
plt.ylabel("Density" , size = 12 )
plt.xlabel("Evaluation" , size = 12 )
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
sn.kdeplot(df.loc[(df['left'] == 0),'average_montly_hours'] , color='red',shade=True,label='Not Left')
sn.kdeplot(df.loc[(df['left'] == 1),'average_montly_hours'] , color='purple',shade=True, label='Left')
plt.title('Employee Average Monthly Hour Distribution - Left v.s. Not Left',size = 13)
plt.ylabel("Density" , size = 12 )
plt.xlabel("Evaluation" , size = 12 )
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
sn.kdeplot(df.loc[(df['left'] == 0),'satisfaction_level'] , color='red',shade=True,label='Not Left')
sn.kdeplot(df.loc[(df['left'] == 1),'satisfaction_level'] , color='purple',shade=True, label='Left')
plt.title('Employee satisfaction Distribution - Left v.s. Not Left',size = 13)
plt.ylabel("Density" , size = 12 )
plt.xlabel("Satisfaction" , size = 12 )
plt.legend()
plt.show()

# %%
left = df.loc[df['left']==1]
not_Left = df.loc[df['left'] == 0]
left.drop("left",axis=1,inplace = True)
not_Left.drop("left",axis=1,inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5788\82705443.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left.drop("left",axis=1,inplace = True)
# C:\Users\user\AppData\Local\Temp\ipykernel_5788\82705443.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_Left.drop("left",axis=1,inplace = True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 10))

ax[0].set_title('Left')
sn.heatmap(left.corr(),annot = True,square = True,ax=ax[0])

ax[1].set_title('Not Left')
sn.heatmap(not_Left.corr(),annot = True,square = True,ax=ax[1])

fig.suptitle("Correlation - Left Vs Not Left", fontsize=16)
plt.tight_layout(pad=3.0)
plt.show()

# %% [raw]
# As we can see from above satisfaction_leve,work_accident,promotion_last_5_years and average monthly hours are highly correlated so will be using them.

# %%
df1=df[["satisfaction_level","average_montly_hours","Work_accident","promotion_last_5years","salary"]]
df1
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 0                    0.38                   157              0
# 1                    0.80                   262              0
# 2                    0.11                   272              0
# 3                    0.72                   223              0
# 4                    0.37                   159              0
# ...                   ...                   ...            ...
# 14994                0.40                   151              0
# 14995                0.37                   160              0
# 14996                0.37                   143              0
# 14997                0.11                   280              0
# 14998                0.37                   158              0
#
#        promotion_last_5years  salary
# 0                          0     low
# 1                          0  medium
# 2                          0  medium
# 3                          0     low
# ...

# %%
target=df.loc[:,'left']

# %%
target
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df1['salary']= le.fit_transform(df['salary'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5788\2934997937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['salary']= le.fit_transform(df['salary'])

# %%
df1
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 0                    0.38                   157              0
# 1                    0.80                   262              0
# 2                    0.11                   272              0
# 3                    0.72                   223              0
# 4                    0.37                   159              0
# ...                   ...                   ...            ...
# 14994                0.40                   151              0
# 14995                0.37                   160              0
# 14996                0.37                   143              0
# 14997                0.11                   280              0
# 14998                0.37                   158              0
#
#        promotion_last_5years  salary
# 0                          0       1
# 1                          0       2
# 2                          0       2
# 3                          0       1
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1,target, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
logistic=LogisticRegression()

# %%
logistic.fit(X_train,y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = logistic.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
score = accuracy_score(y_test, y_pred)

print("Score : ", score)
# Out:
# Score :  0.777
